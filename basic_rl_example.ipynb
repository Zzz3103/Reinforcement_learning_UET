# %%
import numpy as np
import random

# %%
states = ['A', 'B', 'C', 'D', 'E']
actions = [0, 1]
gamma = 1.0
alpha = 0.8
epsilon = 0.25
max_timesteps = 3
rewards = {'A': 1000, 'E': 10, 'B': -1, 'C': -1, 'D': -1}
count_terminal_state = {'A': 0, 'E': 0}

w = np.array([1, 1, -1], dtype=float)

def feature_vector(state, action):
    distance_to_left = states.index(state)
    action_feature = 1 if action == 0 else -1
    return np.array([distance_to_left, action_feature, 1])

def Q_value(state, action, w):
    return np.dot(w, feature_vector(state, action))

def epsilon_greedy(state, w, epsilon):
    if random.random() < epsilon:
        # print("greedy move")
        return random.choice(actions)
    else:
        q_values = [Q_value(state, action, w) for action in actions]
        # print("optimal move")
        return np.argmax(q_values)

# Update Q-values
def update_weights(state, action, next_state, reward, alpha):
    global w
    q_sa = Q_value(state, action, w)
    next_q_values = [Q_value(next_state, next_action, w) for next_action in actions]
    target = reward + gamma * max(next_q_values)
    w += alpha * (target - q_sa) 
    
def q_learning(max_timesteps):
    global w
    state = 'D'  # initial state
    while state not in ['A', 'E'] and max_timesteps > 0:
        action = epsilon_greedy(state, w, epsilon)
        next_state = states[states.index(state) + (1 if action == 1 else -1)]
        reward = rewards[next_state]
        update_weights(state, action, next_state, reward, alpha)

        state = next_state
        
    return state

def main():
    episodes = int(input("Number of episodes "))
    for episode in range(episodes):
        end_state = q_learning(max_timesteps = 3)
        print(f'Episode {episode + 1} State ends in {end_state}')
        count_terminal_state[end_state] += 1
    
    print(f'Agent went to A {count_terminal_state["A"]} times and E {count_terminal_state["E"]} times')
    print(f'final weights: {w}')
if __name__ == "__main__":
  main()
# Out:
# Episode 1 State ends in E
# Episode 2 State ends in A
# Episode 3 State ends in A
# Episode 4 State ends in A
# Episode 5 State ends in A
# Episode 6 State ends in A
# Episode 7 State ends in A
# Episode 8 State ends in A
# Episode 9 State ends in A
# Episode 10 State ends in A
# Episode 11 State ends in A
# Episode 12 State ends in A
# Episode 13 State ends in A
# Episode 14 State ends in A
# Episode 15 State ends in A
# Episode 16 State ends in A
# Episode 17 State ends in A
# Episode 18 State ends in E
# Episode 19 State ends in A
# Episode 20 State ends in A
# Episode 21 State ends in A
# Episode 22 State ends in A
# Episode 23 State ends in E
# Episode 24 State ends in A
# Episode 25 State ends in A
# Episode 26 State ends in A
# Episode 27 State ends in A
# Episode 28 State ends in A
# Episode 29 State ends in E
# Episode 30 State ends in A
# Episode 31 State ends in A
# Episode 32 State ends in A
# Episode 33 State ends in A
# Episode 34 State ends in A
# Episode 35 State ends in A
# Episode 36 State ends in A
# Episode 37 State ends in A
# Episode 38 State ends in A
# Episode 39 State ends in A
# Episode 40 State ends in A
# Episode 41 State ends in A
# Episode 42 State ends in A
# Episode 43 State ends in A
# Episode 44 State ends in A
# Episode 45 State ends in E
# Episode 46 State ends in A
# Episode 47 State ends in A
# Episode 48 State ends in A
# Episode 49 State ends in A
# Episode 50 State ends in A
# Episode 51 State ends in A
# Episode 52 State ends in A
# Episode 53 State ends in A
# Episode 54 State ends in A
# Episode 55 State ends in A
# Episode 56 State ends in A
# Episode 57 State ends in A
# Episode 58 State ends in A
# Episode 59 State ends in A
# Episode 60 State ends in A
# Episode 61 State ends in A
# Episode 62 State ends in A
# Episode 63 State ends in A
# Episode 64 State ends in A
# Episode 65 State ends in A
# Episode 66 State ends in A
# Episode 67 State ends in A
# Episode 68 State ends in A
# Episode 69 State ends in E
# Episode 70 State ends in A
# Episode 71 State ends in A
# Episode 72 State ends in A
# Episode 73 State ends in A
# Episode 74 State ends in A
# Episode 75 State ends in A
# Episode 76 State ends in A
# Episode 77 State ends in A
# Episode 78 State ends in A
# Episode 79 State ends in E
# Episode 80 State ends in A
# Episode 81 State ends in A
# Episode 82 State ends in A
# Episode 83 State ends in E
# Episode 84 State ends in A
# Episode 85 State ends in A
# Episode 86 State ends in A
# Episode 87 State ends in E
# Episode 88 State ends in E
# Episode 89 State ends in A
# Episode 90 State ends in A
# Episode 91 State ends in A
# Episode 92 State ends in A
# Episode 93 State ends in A
# Episode 94 State ends in A
# Episode 95 State ends in A
# Episode 96 State ends in A
# Episode 97 State ends in A
# Episode 98 State ends in E
# Episode 99 State ends in A
# Episode 100 State ends in A
# Episode 101 State ends in A
# Episode 102 State ends in E
# Episode 103 State ends in A
# Episode 104 State ends in A
# Episode 105 State ends in A
# Episode 106 State ends in A
# Episode 107 State ends in A
# Episode 108 State ends in A
# Episode 109 State ends in A
# Episode 110 State ends in A
# Episode 111 State ends in A
# Episode 112 State ends in A
# Episode 113 State ends in A
# Episode 114 State ends in A
# Episode 115 State ends in E
# Episode 116 State ends in A
# Episode 117 State ends in E
# Episode 118 State ends in A
# Episode 119 State ends in A
# Episode 120 State ends in A
# Episode 121 State ends in A
# Episode 122 State ends in A
# Episode 123 State ends in A
# Episode 124 State ends in A
# Episode 125 State ends in A
# Episode 126 State ends in A
# Episode 127 State ends in A
# Episode 128 State ends in A
# Episode 129 State ends in A
# Episode 130 State ends in A
# Episode 131 State ends in A
# Episode 132 State ends in A
# Episode 133 State ends in A
# Episode 134 State ends in A
# Episode 135 State ends in E
# Episode 136 State ends in E
# Episode 137 State ends in E
# Episode 138 State ends in A
# Episode 139 State ends in A
# Episode 140 State ends in A
# Episode 141 State ends in E
# Episode 142 State ends in A
# Episode 143 State ends in A
# Episode 144 State ends in E
# Episode 145 State ends in E
# Episode 146 State ends in A
# Episode 147 State ends in A
# Episode 148 State ends in A
# Episode 149 State ends in A
# Episode 150 State ends in E
# Episode 151 State ends in A
# Episode 152 State ends in A
# Episode 153 State ends in A
# Episode 154 State ends in E
# Episode 155 State ends in A
# Episode 156 State ends in A
# Episode 157 State ends in E
# Episode 158 State ends in A
# Episode 159 State ends in A
# Episode 160 State ends in A
# Episode 161 State ends in A
# Episode 162 State ends in A
# Episode 163 State ends in A
# Episode 164 State ends in A
# Episode 165 State ends in A
# Episode 166 State ends in E
# Episode 167 State ends in A
# Episode 168 State ends in A
# Episode 169 State ends in A
# Episode 170 State ends in A
# Episode 171 State ends in A
# Episode 172 State ends in A
# Episode 173 State ends in A
# Episode 174 State ends in A
# Episode 175 State ends in A
# Episode 176 State ends in A
# Episode 177 State ends in E
# Episode 178 State ends in A
# Episode 179 State ends in A
# Episode 180 State ends in A
# Episode 181 State ends in A
# Episode 182 State ends in A
# Episode 183 State ends in E
# Episode 184 State ends in A
# Episode 185 State ends in A
# Episode 186 State ends in A
# Episode 187 State ends in A
# Episode 188 State ends in A
# Episode 189 State ends in A
# Episode 190 State ends in E
# Episode 191 State ends in A
# Episode 192 State ends in A
# Episode 193 State ends in A
# Episode 194 State ends in A
# Episode 195 State ends in A
# Episode 196 State ends in A
# Episode 197 State ends in A
# Episode 198 State ends in A
# Episode 199 State ends in A
# Episode 200 State ends in A
# Episode 201 State ends in A
# Episode 202 State ends in A
# Episode 203 State ends in A
# Episode 204 State ends in A
# Episode 205 State ends in A
# Episode 206 State ends in A
# Episode 207 State ends in A
# Episode 208 State ends in A
# Episode 209 State ends in A
# Episode 210 State ends in A
# Episode 211 State ends in A
# Episode 212 State ends in E
# Episode 213 State ends in A
# Episode 214 State ends in A
# Episode 215 State ends in E
# Episode 216 State ends in A
# Episode 217 State ends in A
# Episode 218 State ends in A
# Episode 219 State ends in A
# Episode 220 State ends in A
# Episode 221 State ends in A
# Episode 222 State ends in A
# Episode 223 State ends in A
# Episode 224 State ends in E
# Episode 225 State ends in A
# Episode 226 State ends in A
# Episode 227 State ends in E
# Episode 228 State ends in A
# Episode 229 State ends in A
# Episode 230 State ends in A
# Episode 231 State ends in A
# Episode 232 State ends in A
# Episode 233 State ends in A
# Episode 234 State ends in A
# Episode 235 State ends in A
# Episode 236 State ends in A
# Episode 237 State ends in A
# Episode 238 State ends in A
# Episode 239 State ends in A
# Episode 240 State ends in A
# Episode 241 State ends in E
# Episode 242 State ends in A
# Episode 243 State ends in A
# Episode 244 State ends in A
# Episode 245 State ends in A
# Episode 246 State ends in A
# Episode 247 State ends in A
# Episode 248 State ends in E
# Episode 249 State ends in A
# Episode 250 State ends in A
# Episode 251 State ends in A
# Episode 252 State ends in E
# Episode 253 State ends in A
# Episode 254 State ends in A
# Episode 255 State ends in A
# Episode 256 State ends in A
# Episode 257 State ends in A
# Episode 258 State ends in E
# Episode 259 State ends in A
# Episode 260 State ends in A
# Episode 261 State ends in A
# Episode 262 State ends in A
# Episode 263 State ends in A
# Episode 264 State ends in A
# Episode 265 State ends in A
# Episode 266 State ends in A
# Episode 267 State ends in A
# Episode 268 State ends in A
# Episode 269 State ends in A
# Episode 270 State ends in A
# Episode 271 State ends in A
# Episode 272 State ends in E
# Episode 273 State ends in A
# Episode 274 State ends in A
# Episode 275 State ends in E
# Episode 276 State ends in A
# Episode 277 State ends in A
# Episode 278 State ends in A
# Episode 279 State ends in A
# Episode 280 State ends in A
# Episode 281 State ends in A
# Episode 282 State ends in A
# Episode 283 State ends in A
# Episode 284 State ends in A
# Episode 285 State ends in E
# Episode 286 State ends in A
# Episode 287 State ends in E
# Episode 288 State ends in A
# Episode 289 State ends in A
# Episode 290 State ends in A
# Episode 291 State ends in A
# Episode 292 State ends in A
# Episode 293 State ends in A
# Episode 294 State ends in A
# Episode 295 State ends in A
# Episode 296 State ends in A
# Episode 297 State ends in A
# Episode 298 State ends in A
# Episode 299 State ends in A
# Episode 300 State ends in E
# Episode 301 State ends in E
# Episode 302 State ends in A
# Episode 303 State ends in A
# Episode 304 State ends in A
# Episode 305 State ends in A
# Episode 306 State ends in A
# Episode 307 State ends in A
# Episode 308 State ends in A
# Episode 309 State ends in A
# Episode 310 State ends in A
# Episode 311 State ends in A
# Episode 312 State ends in A
# Episode 313 State ends in E
# Episode 314 State ends in E
# Episode 315 State ends in A
# Episode 316 State ends in A
# Episode 317 State ends in A
# Episode 318 State ends in A
# Episode 319 State ends in A
# Episode 320 State ends in E
# Episode 321 State ends in A
# Episode 322 State ends in A
# Episode 323 State ends in A
# Episode 324 State ends in A
# Episode 325 State ends in A
# Episode 326 State ends in A
# Episode 327 State ends in A
# Episode 328 State ends in A
# Episode 329 State ends in A
# Episode 330 State ends in A
# Episode 331 State ends in A
# Episode 332 State ends in E
# Episode 333 State ends in A
# Episode 334 State ends in A
# Episode 335 State ends in A
# Episode 336 State ends in A
# Episode 337 State ends in A
# Episode 338 State ends in A
# Episode 339 State ends in A
# Episode 340 State ends in A
# Episode 341 State ends in A
# Episode 342 State ends in A
# Episode 343 State ends in E
# Episode 344 State ends in A
# Episode 345 State ends in A
# Episode 346 State ends in E
# Episode 347 State ends in A
# Episode 348 State ends in A
# Episode 349 State ends in A
# Episode 350 State ends in A
# Episode 351 State ends in A
# Episode 352 State ends in A
# Episode 353 State ends in E
# Episode 354 State ends in A
# Episode 355 State ends in A
# Episode 356 State ends in A
# Episode 357 State ends in A
# Episode 358 State ends in A
# Episode 359 State ends in E
# Episode 360 State ends in A
# Episode 361 State ends in A
# Episode 362 State ends in A
# Episode 363 State ends in A
# Episode 364 State ends in E
# Episode 365 State ends in E
# Episode 366 State ends in A
# Episode 367 State ends in A
# Episode 368 State ends in A
# Episode 369 State ends in A
# Episode 370 State ends in A
# Episode 371 State ends in E
# Episode 372 State ends in A
# Episode 373 State ends in A
# Episode 374 State ends in A
# Episode 375 State ends in A
# Episode 376 State ends in A
# Episode 377 State ends in A
# Episode 378 State ends in A
# Episode 379 State ends in A
# Episode 380 State ends in A
# Episode 381 State ends in A
# Episode 382 State ends in A
# Episode 383 State ends in E
# Episode 384 State ends in E
# Episode 385 State ends in A
# Episode 386 State ends in A
# Episode 387 State ends in A
# Episode 388 State ends in A
# Episode 389 State ends in A
# Episode 390 State ends in A
# Episode 391 State ends in A
# Episode 392 State ends in A
# Episode 393 State ends in A
# Episode 394 State ends in A
# Episode 395 State ends in A
# Episode 396 State ends in A
# Episode 397 State ends in A
# Episode 398 State ends in A
# Episode 399 State ends in A
# Episode 400 State ends in A
# Episode 401 State ends in A
# Episode 402 State ends in A
# Episode 403 State ends in A
# Episode 404 State ends in A
# Episode 405 State ends in A
# Episode 406 State ends in A
# Episode 407 State ends in A
# Episode 408 State ends in A
# Episode 409 State ends in A
# Episode 410 State ends in A
# Episode 411 State ends in E
# Episode 412 State ends in A
# Episode 413 State ends in A
# Episode 414 State ends in A
# Episode 415 State ends in A
# Episode 416 State ends in A
# Episode 417 State ends in A
# Episode 418 State ends in A
# Episode 419 State ends in A
# Episode 420 State ends in A
# Episode 421 State ends in A
# Episode 422 State ends in A
# Episode 423 State ends in A
# Episode 424 State ends in A
# Episode 425 State ends in A
# Episode 426 State ends in A
# Episode 427 State ends in A
# Episode 428 State ends in E
# Episode 429 State ends in A
# Episode 430 State ends in A
# Episode 431 State ends in A
# Episode 432 State ends in A
# Episode 433 State ends in A
# Episode 434 State ends in A
# Episode 435 State ends in A
# Episode 436 State ends in E
# Episode 437 State ends in A
# Episode 438 State ends in A
# Episode 439 State ends in A
# Episode 440 State ends in A
# Episode 441 State ends in A
# Episode 442 State ends in A
# Episode 443 State ends in E
# Episode 444 State ends in E
# Episode 445 State ends in A
# Episode 446 State ends in E
# Episode 447 State ends in A
# Episode 448 State ends in A
# Episode 449 State ends in A
# Episode 450 State ends in A
# Episode 451 State ends in A
# Episode 452 State ends in A
# Episode 453 State ends in E
# Episode 454 State ends in A
# Episode 455 State ends in A
# Episode 456 State ends in E
# Episode 457 State ends in A
# Episode 458 State ends in A
# Episode 459 State ends in A
# Episode 460 State ends in A
# Episode 461 State ends in A
# Episode 462 State ends in A
# Episode 463 State ends in A
# Episode 464 State ends in A
# Episode 465 State ends in A
# Episode 466 State ends in A
# Episode 467 State ends in A
# Episode 468 State ends in A
# Episode 469 State ends in E
# Episode 470 State ends in A
# Episode 471 State ends in A
# Episode 472 State ends in A
# Episode 473 State ends in A
# Episode 474 State ends in A
# Episode 475 State ends in A
# Episode 476 State ends in E
# Episode 477 State ends in A
# Episode 478 State ends in A
# Episode 479 State ends in A
# Episode 480 State ends in A
# Episode 481 State ends in A
# Episode 482 State ends in A
# Episode 483 State ends in A
# Episode 484 State ends in A
# Episode 485 State ends in A
# Episode 486 State ends in E
# Episode 487 State ends in A
# Episode 488 State ends in A
# Episode 489 State ends in A
# Episode 490 State ends in A
# Episode 491 State ends in A
# Episode 492 State ends in A
# Episode 493 State ends in A
# Episode 494 State ends in A
# Episode 495 State ends in A
# Episode 496 State ends in A
# Episode 497 State ends in A
# Episode 498 State ends in A
# Episode 499 State ends in A
# Episode 500 State ends in E
# Episode 501 State ends in A
# Episode 502 State ends in A
# Episode 503 State ends in A
# Episode 504 State ends in A
# Episode 505 State ends in A
# Episode 506 State ends in E
# Episode 507 State ends in A
# Episode 508 State ends in A
# Episode 509 State ends in A
# Episode 510 State ends in A
# Episode 511 State ends in A
# Episode 512 State ends in A
# Episode 513 State ends in E
# Episode 514 State ends in E
# Episode 515 State ends in A
# Episode 516 State ends in A
# Episode 517 State ends in A
# Episode 518 State ends in A
# Episode 519 State ends in A
# Episode 520 State ends in A
# Episode 521 State ends in A
# Episode 522 State ends in A
# Episode 523 State ends in A
# Episode 524 State ends in A
# Episode 525 State ends in A
# Episode 526 State ends in A
# Episode 527 State ends in A
# Episode 528 State ends in A
# Episode 529 State ends in A
# Episode 530 State ends in A
# Episode 531 State ends in A
# Episode 532 State ends in A
# Episode 533 State ends in A
# Episode 534 State ends in A
# Episode 535 State ends in E
# Episode 536 State ends in A
# Episode 537 State ends in A
# Episode 538 State ends in A
# Episode 539 State ends in A
# Episode 540 State ends in A
# Episode 541 State ends in A
# Episode 542 State ends in A
# Episode 543 State ends in A
# Episode 544 State ends in A
# Episode 545 State ends in A
# Episode 546 State ends in A
# Episode 547 State ends in A
# Episode 548 State ends in A
# Episode 549 State ends in A
# Episode 550 State ends in A
# Episode 551 State ends in E
# Episode 552 State ends in A
# Episode 553 State ends in E
# Episode 554 State ends in A
# Episode 555 State ends in E
# Episode 556 State ends in A
# Episode 557 State ends in A
# Episode 558 State ends in A
# Episode 559 State ends in A
# Episode 560 State ends in A
# Episode 561 State ends in A
# Episode 562 State ends in A
# Episode 563 State ends in A
# Episode 564 State ends in A
# Episode 565 State ends in A
# Episode 566 State ends in A
# Episode 567 State ends in A
# Episode 568 State ends in A
# Episode 569 State ends in A
# Episode 570 State ends in A
# Episode 571 State ends in A
# Episode 572 State ends in E
# Episode 573 State ends in A
# Episode 574 State ends in A
# Episode 575 State ends in A
# Episode 576 State ends in A
# Episode 577 State ends in A
# Episode 578 State ends in A
# Episode 579 State ends in A
# Episode 580 State ends in A
# Episode 581 State ends in A
# Episode 582 State ends in E
# Episode 583 State ends in A
# Episode 584 State ends in E
# Episode 585 State ends in E
# Episode 586 State ends in A
# Episode 587 State ends in A
# Episode 588 State ends in A
# Episode 589 State ends in A
# Episode 590 State ends in A
# Episode 591 State ends in A
# Episode 592 State ends in A
# Episode 593 State ends in A
# Episode 594 State ends in A
# Episode 595 State ends in A
# Episode 596 State ends in A
# Episode 597 State ends in E
# Episode 598 State ends in A
# Episode 599 State ends in A
# Episode 600 State ends in A
# Episode 601 State ends in A
# Episode 602 State ends in A
# Episode 603 State ends in E
# Episode 604 State ends in A
# Episode 605 State ends in A
# Episode 606 State ends in A
# Episode 607 State ends in A
# Episode 608 State ends in A
# Episode 609 State ends in A
# Episode 610 State ends in E
# Episode 611 State ends in A
# Episode 612 State ends in A
# Episode 613 State ends in A
# Episode 614 State ends in A
# Episode 615 State ends in E
# Episode 616 State ends in A
# Episode 617 State ends in A
# Episode 618 State ends in E
# Episode 619 State ends in A
# Episode 620 State ends in A
# Episode 621 State ends in A
# Episode 622 State ends in A
# Episode 623 State ends in E
# Episode 624 State ends in A
# Episode 625 State ends in E
# Episode 626 State ends in A
# Episode 627 State ends in A
# Episode 628 State ends in A
# Episode 629 State ends in A
# Episode 630 State ends in A
# Episode 631 State ends in A
# Episode 632 State ends in A
# Episode 633 State ends in A
# Episode 634 State ends in A
# Episode 635 State ends in A
# Episode 636 State ends in E
# Episode 637 State ends in A
# Episode 638 State ends in A
# Episode 639 State ends in E
# Episode 640 State ends in A
# Episode 641 State ends in A
# Episode 642 State ends in A
# Episode 643 State ends in A
# Episode 644 State ends in A
# Episode 645 State ends in A
# Episode 646 State ends in E
# Episode 647 State ends in A
# Episode 648 State ends in A
# Episode 649 State ends in E
# Episode 650 State ends in A
# Episode 651 State ends in A
# Episode 652 State ends in A
# Episode 653 State ends in A
# Episode 654 State ends in A
# Episode 655 State ends in A
# Episode 656 State ends in A
# Episode 657 State ends in E
# Episode 658 State ends in A
# Episode 659 State ends in A
# Episode 660 State ends in A
# Episode 661 State ends in A
# Episode 662 State ends in E
# Episode 663 State ends in A
# Episode 664 State ends in A
# Episode 665 State ends in A
# Episode 666 State ends in A
# Episode 667 State ends in A
# Episode 668 State ends in A
# Episode 669 State ends in A
# Episode 670 State ends in A
# Episode 671 State ends in A
# Episode 672 State ends in E
# Episode 673 State ends in A
# Episode 674 State ends in A
# Episode 675 State ends in E
# Episode 676 State ends in A
# Episode 677 State ends in A
# Episode 678 State ends in A
# Episode 679 State ends in E
# Episode 680 State ends in A
# Episode 681 State ends in A
# Episode 682 State ends in A
# Episode 683 State ends in A
# Episode 684 State ends in A
# Episode 685 State ends in A
# Episode 686 State ends in A
# Episode 687 State ends in A
# Episode 688 State ends in A
# Episode 689 State ends in E
# Episode 690 State ends in A
# Episode 691 State ends in A
# Episode 692 State ends in A
# Episode 693 State ends in A
# Episode 694 State ends in A
# Episode 695 State ends in A
# Episode 696 State ends in A
# Episode 697 State ends in A
# Episode 698 State ends in A
# Episode 699 State ends in A
# Episode 700 State ends in A
# Episode 701 State ends in A
# Episode 702 State ends in A
# Episode 703 State ends in A
# Episode 704 State ends in A
# Episode 705 State ends in E
# Episode 706 State ends in A
# Episode 707 State ends in A
# Episode 708 State ends in A
# Episode 709 State ends in A
# Episode 710 State ends in A
# Episode 711 State ends in A
# Episode 712 State ends in A
# Episode 713 State ends in A
# Episode 714 State ends in A
# Episode 715 State ends in A
# Episode 716 State ends in A
# Episode 717 State ends in A
# Episode 718 State ends in E
# Episode 719 State ends in A
# Episode 720 State ends in A
# Episode 721 State ends in A
# Episode 722 State ends in A
# Episode 723 State ends in A
# Episode 724 State ends in A
# Episode 725 State ends in E
# Episode 726 State ends in A
# Episode 727 State ends in A
# Episode 728 State ends in A
# Episode 729 State ends in A
# Episode 730 State ends in E
# Episode 731 State ends in A
# Episode 732 State ends in A
# Episode 733 State ends in A
# Episode 734 State ends in A
# Episode 735 State ends in A
# Episode 736 State ends in A
# Episode 737 State ends in A
# Episode 738 State ends in A
# Episode 739 State ends in E
# Episode 740 State ends in E
# Episode 741 State ends in A
# Episode 742 State ends in A
# Episode 743 State ends in E
# Episode 744 State ends in A
# Episode 745 State ends in A
# Episode 746 State ends in A
# Episode 747 State ends in A
# Episode 748 State ends in A
# Episode 749 State ends in A
# Episode 750 State ends in A
# Episode 751 State ends in A
# Episode 752 State ends in A
# Episode 753 State ends in A
# Episode 754 State ends in A
# Episode 755 State ends in A
# Episode 756 State ends in A
# Episode 757 State ends in A
# Episode 758 State ends in A
# Episode 759 State ends in A
# Episode 760 State ends in A
# Episode 761 State ends in A
# Episode 762 State ends in A
# Episode 763 State ends in A
# Episode 764 State ends in A
# Episode 765 State ends in A
# Episode 766 State ends in A
# Episode 767 State ends in A
# Episode 768 State ends in A
# Episode 769 State ends in A
# Episode 770 State ends in A
# Episode 771 State ends in E
# Episode 772 State ends in A
# Episode 773 State ends in E
# Episode 774 State ends in A
# Episode 775 State ends in A
# Episode 776 State ends in A
# Episode 777 State ends in A
# Episode 778 State ends in A
# Episode 779 State ends in A
# Episode 780 State ends in A
# Episode 781 State ends in E
# Episode 782 State ends in E
# Episode 783 State ends in A
# Episode 784 State ends in A
# Episode 785 State ends in A
# Episode 786 State ends in A
# Episode 787 State ends in E
# Episode 788 State ends in A
# Episode 789 State ends in A
# Episode 790 State ends in A
# Episode 791 State ends in A
# Episode 792 State ends in E
# Episode 793 State ends in E
# Episode 794 State ends in A
# Episode 795 State ends in A
# Episode 796 State ends in A
# Episode 797 State ends in E
# Episode 798 State ends in A
# Episode 799 State ends in E
# Episode 800 State ends in E
# Episode 801 State ends in A
# Episode 802 State ends in E
# Episode 803 State ends in A
# Episode 804 State ends in A
# Episode 805 State ends in A
# Episode 806 State ends in A
# Episode 807 State ends in E
# Episode 808 State ends in A
# Episode 809 State ends in A
# Episode 810 State ends in A
# Episode 811 State ends in A
# Episode 812 State ends in A
# Episode 813 State ends in A
# Episode 814 State ends in A
# Episode 815 State ends in E
# Episode 816 State ends in A
# Episode 817 State ends in A
# Episode 818 State ends in E
# Episode 819 State ends in A
# Episode 820 State ends in A
# Episode 821 State ends in A
# Episode 822 State ends in A
# Episode 823 State ends in A
# Episode 824 State ends in E
# Episode 825 State ends in A
# Episode 826 State ends in A
# Episode 827 State ends in E
# Episode 828 State ends in E
# Episode 829 State ends in A
# Episode 830 State ends in A
# Episode 831 State ends in A
# Episode 832 State ends in A
# Episode 833 State ends in E
# Episode 834 State ends in A
# Episode 835 State ends in A
# Episode 836 State ends in A
# Episode 837 State ends in A
# Episode 838 State ends in A
# Episode 839 State ends in A
# Episode 840 State ends in A
# Episode 841 State ends in A
# Episode 842 State ends in A
# Episode 843 State ends in E
# Episode 844 State ends in A
# Episode 845 State ends in A
# Episode 846 State ends in A
# Episode 847 State ends in A
# Episode 848 State ends in A
# Episode 849 State ends in A
# Episode 850 State ends in A
# Episode 851 State ends in A
# Episode 852 State ends in A
# Episode 853 State ends in A
# Episode 854 State ends in A
# Episode 855 State ends in A
# Episode 856 State ends in A
# Episode 857 State ends in A
# Episode 858 State ends in E
# Episode 859 State ends in A
# Episode 860 State ends in A
# Episode 861 State ends in A
# Episode 862 State ends in A
# Episode 863 State ends in A
# Episode 864 State ends in A
# Episode 865 State ends in A
# Episode 866 State ends in A
# Episode 867 State ends in A
# Episode 868 State ends in A
# Episode 869 State ends in A
# Episode 870 State ends in A
# Episode 871 State ends in A
# Episode 872 State ends in A
# Episode 873 State ends in A
# Episode 874 State ends in A
# Episode 875 State ends in A
# Episode 876 State ends in A
# Episode 877 State ends in A
# Episode 878 State ends in E
# Episode 879 State ends in A
# Episode 880 State ends in A
# Episode 881 State ends in A
# Episode 882 State ends in A
# Episode 883 State ends in A
# Episode 884 State ends in E
# Episode 885 State ends in A
# Episode 886 State ends in A
# Episode 887 State ends in A
# Episode 888 State ends in A
# Episode 889 State ends in A
# Episode 890 State ends in A
# Episode 891 State ends in A
# Episode 892 State ends in A
# Episode 893 State ends in A
# Episode 894 State ends in A
# Episode 895 State ends in A
# Episode 896 State ends in A
# Episode 897 State ends in A
# Episode 898 State ends in E
# Episode 899 State ends in A
# Episode 900 State ends in A
# Episode 901 State ends in A
# Episode 902 State ends in A
# Episode 903 State ends in A
# Episode 904 State ends in A
# Episode 905 State ends in A
# Episode 906 State ends in E
# Episode 907 State ends in A
# Episode 908 State ends in A
# Episode 909 State ends in A
# Episode 910 State ends in A
# Episode 911 State ends in A
# Episode 912 State ends in A
# Episode 913 State ends in E
# Episode 914 State ends in A
# Episode 915 State ends in A
# Episode 916 State ends in A
# Episode 917 State ends in A
# Episode 918 State ends in A
# Episode 919 State ends in A
# Episode 920 State ends in A
# Episode 921 State ends in A
# Episode 922 State ends in A
# Episode 923 State ends in E
# Episode 924 State ends in E
# Episode 925 State ends in A
# Episode 926 State ends in A
# Episode 927 State ends in A
# Episode 928 State ends in A
# Episode 929 State ends in A
# Episode 930 State ends in E
# Episode 931 State ends in A
# Episode 932 State ends in A
# Episode 933 State ends in A
# Episode 934 State ends in A
# Episode 935 State ends in A
# Episode 936 State ends in A
# Episode 937 State ends in A
# Episode 938 State ends in A
# Episode 939 State ends in E
# Episode 940 State ends in A
# Episode 941 State ends in E
# Episode 942 State ends in E
# Episode 943 State ends in E
# Episode 944 State ends in A
# Episode 945 State ends in A
# Episode 946 State ends in A
# Episode 947 State ends in A
# Episode 948 State ends in A
# Episode 949 State ends in A
# Episode 950 State ends in A
# Episode 951 State ends in A
# Episode 952 State ends in A
# Episode 953 State ends in E
# Episode 954 State ends in A
# Episode 955 State ends in A
# Episode 956 State ends in A
# Episode 957 State ends in E
# Episode 958 State ends in A
# Episode 959 State ends in A
# Episode 960 State ends in A
# Episode 961 State ends in A
# Episode 962 State ends in A
# Episode 963 State ends in A
# Episode 964 State ends in A
# Episode 965 State ends in A
# Episode 966 State ends in A
# Episode 967 State ends in A
# Episode 968 State ends in A
# Episode 969 State ends in A
# Episode 970 State ends in A
# Episode 971 State ends in A
# Episode 972 State ends in A
# Episode 973 State ends in A
# Episode 974 State ends in A
# Episode 975 State ends in A
# Episode 976 State ends in E
# Episode 977 State ends in A
# Episode 978 State ends in A
# Episode 979 State ends in A
# Episode 980 State ends in A
# Episode 981 State ends in A
# Episode 982 State ends in A
# Episode 983 State ends in A
# Episode 984 State ends in A
# Episode 985 State ends in A
# Episode 986 State ends in A
# Episode 987 State ends in A
# Episode 988 State ends in A
# Episode 989 State ends in A
# Episode 990 State ends in A
# Episode 991 State ends in A
# Episode 992 State ends in A
# Episode 993 State ends in A
# Episode 994 State ends in A
# Episode 995 State ends in A
# Episode 996 State ends in A
# Episode 997 State ends in A
# Episode 998 State ends in A
# Episode 999 State ends in A
# Episode 1000 State ends in A
# Agent went to A 864 times and E 136 times
# final weights: [806.24123602 806.24123602 804.24123602]

# %%
def reset():
    global count_terminal_state
    count_terminal_state = {'A': 0, 'E': 0}

w1 = np.array([1,1,-1], dtype = float)
w2 = np.array([1,1,-1], dtype = float)

def update_weights_2_vectors(state, action, next_state, reward, alpha, w):
    q_sa = Q_value(state, action, w)
    next_q_values = [Q_value(next_state, next_action, w) for next_action in actions]
    target = reward + gamma * max(next_q_values)
    w += alpha * (target - q_sa) 
    
def q_learning_2_vectors(max_timesteps):
    global w1, w2
    state = 'D'  # initial state
    while state not in ['A', 'E'] and max_timesteps > 0:
        action = epsilon_greedy(state, w, epsilon)
        next_state = states[states.index(state) + (1 if action == 1 else -1)]
        reward = rewards[next_state]
        if action == 0:
            update_weights_2_vectors(state, action, next_state, reward, alpha, w1)
        else:
            update_weights_2_vectors(state, action, next_state, reward, alpha, w2)
        state = next_state
        
    return state

def main():
    reset()
    episodes = int(input("Number of episodes "))
    for episode in range(episodes):
        end_state = q_learning_2_vectors(max_timesteps = 3)
        print(f'Episode {episode + 1} State ends in {end_state}')
        count_terminal_state[end_state] += 1
    
    print(f'Agent went to A {count_terminal_state["A"]} times and E {count_terminal_state["E"]} times')
    print(f'final weights: w1:{w1} || w2: {w2}')
if __name__ == "__main__":
    main()
# Out:
# Episode 1 State ends in A
# Episode 2 State ends in A
# Episode 3 State ends in A
# Episode 4 State ends in A
# Episode 5 State ends in A
# Episode 6 State ends in E
# Episode 7 State ends in A
# Episode 8 State ends in A
# Episode 9 State ends in A
# Episode 10 State ends in A
# Episode 11 State ends in A
# Episode 12 State ends in A
# Episode 13 State ends in A
# Episode 14 State ends in E
# Episode 15 State ends in A
# Episode 16 State ends in E
# Episode 17 State ends in A
# Episode 18 State ends in A
# Episode 19 State ends in A
# Episode 20 State ends in A
# Episode 21 State ends in A
# Episode 22 State ends in A
# Episode 23 State ends in A
# Episode 24 State ends in A
# Episode 25 State ends in A
# Episode 26 State ends in A
# Episode 27 State ends in A
# Episode 28 State ends in A
# Episode 29 State ends in A
# Episode 30 State ends in A
# Episode 31 State ends in A
# Episode 32 State ends in A
# Episode 33 State ends in A
# Episode 34 State ends in A
# Episode 35 State ends in A
# Episode 36 State ends in A
# Episode 37 State ends in E
# Episode 38 State ends in A
# Episode 39 State ends in A
# Episode 40 State ends in A
# Episode 41 State ends in A
# Episode 42 State ends in A
# Episode 43 State ends in A
# Episode 44 State ends in A
# Episode 45 State ends in A
# Episode 46 State ends in A
# Episode 47 State ends in A
# Episode 48 State ends in A
# Episode 49 State ends in A
# Episode 50 State ends in A
# Episode 51 State ends in A
# Episode 52 State ends in A
# Episode 53 State ends in A
# Episode 54 State ends in A
# Episode 55 State ends in A
# Episode 56 State ends in A
# Episode 57 State ends in A
# Episode 58 State ends in A
# Episode 59 State ends in A
# Episode 60 State ends in A
# Episode 61 State ends in A
# Episode 62 State ends in A
# Episode 63 State ends in A
# Episode 64 State ends in A
# Episode 65 State ends in A
# Episode 66 State ends in A
# Episode 67 State ends in E
# Episode 68 State ends in A
# Episode 69 State ends in E
# Episode 70 State ends in A
# Episode 71 State ends in E
# Episode 72 State ends in A
# Episode 73 State ends in E
# Episode 74 State ends in A
# Episode 75 State ends in A
# Episode 76 State ends in A
# Episode 77 State ends in A
# Episode 78 State ends in A
# Episode 79 State ends in A
# Episode 80 State ends in E
# Episode 81 State ends in A
# Episode 82 State ends in A
# Episode 83 State ends in A
# Episode 84 State ends in A
# Episode 85 State ends in A
# Episode 86 State ends in A
# Episode 87 State ends in A
# Episode 88 State ends in A
# Episode 89 State ends in A
# Episode 90 State ends in A
# Episode 91 State ends in A
# Episode 92 State ends in A
# Episode 93 State ends in A
# Episode 94 State ends in A
# Episode 95 State ends in A
# Episode 96 State ends in A
# Episode 97 State ends in E
# Episode 98 State ends in A
# Episode 99 State ends in E
# Episode 100 State ends in A
# Episode 101 State ends in A
# Episode 102 State ends in A
# Episode 103 State ends in A
# Episode 104 State ends in A
# Episode 105 State ends in A
# Episode 106 State ends in E
# Episode 107 State ends in A
# Episode 108 State ends in A
# Episode 109 State ends in A
# Episode 110 State ends in A
# Episode 111 State ends in E
# Episode 112 State ends in E
# Episode 113 State ends in A
# Episode 114 State ends in A
# Episode 115 State ends in A
# Episode 116 State ends in A
# Episode 117 State ends in A
# Episode 118 State ends in A
# Episode 119 State ends in A
# Episode 120 State ends in A
# Episode 121 State ends in A
# Episode 122 State ends in A
# Episode 123 State ends in E
# Episode 124 State ends in A
# Episode 125 State ends in A
# Episode 126 State ends in A
# Episode 127 State ends in A
# Episode 128 State ends in A
# Episode 129 State ends in A
# Episode 130 State ends in A
# Episode 131 State ends in A
# Episode 132 State ends in A
# Episode 133 State ends in A
# Episode 134 State ends in A
# Episode 135 State ends in A
# Episode 136 State ends in A
# Episode 137 State ends in E
# Episode 138 State ends in E
# Episode 139 State ends in A
# Episode 140 State ends in A
# Episode 141 State ends in A
# Episode 142 State ends in A
# Episode 143 State ends in A
# Episode 144 State ends in A
# Episode 145 State ends in E
# Episode 146 State ends in A
# Episode 147 State ends in A
# Episode 148 State ends in A
# Episode 149 State ends in A
# Episode 150 State ends in A
# Episode 151 State ends in A
# Episode 152 State ends in A
# Episode 153 State ends in A
# Episode 154 State ends in A
# Episode 155 State ends in A
# Episode 156 State ends in A
# Episode 157 State ends in A
# Episode 158 State ends in E
# Episode 159 State ends in A
# Episode 160 State ends in A
# Episode 161 State ends in A
# Episode 162 State ends in A
# Episode 163 State ends in A
# Episode 164 State ends in A
# Episode 165 State ends in A
# Episode 166 State ends in E
# Episode 167 State ends in A
# Episode 168 State ends in A
# Episode 169 State ends in A
# Episode 170 State ends in A
# Episode 171 State ends in A
# Episode 172 State ends in E
# Episode 173 State ends in A
# Episode 174 State ends in A
# Episode 175 State ends in A
# Episode 176 State ends in A
# Episode 177 State ends in A
# Episode 178 State ends in E
# Episode 179 State ends in A
# Episode 180 State ends in E
# Episode 181 State ends in A
# Episode 182 State ends in A
# Episode 183 State ends in A
# Episode 184 State ends in A
# Episode 185 State ends in E
# Episode 186 State ends in A
# Episode 187 State ends in A
# Episode 188 State ends in A
# Episode 189 State ends in A
# Episode 190 State ends in A
# Episode 191 State ends in A
# Episode 192 State ends in A
# Episode 193 State ends in E
# Episode 194 State ends in A
# Episode 195 State ends in A
# Episode 196 State ends in A
# Episode 197 State ends in A
# Episode 198 State ends in A
# Episode 199 State ends in A
# Episode 200 State ends in A
# Episode 201 State ends in A
# Episode 202 State ends in A
# Episode 203 State ends in A
# Episode 204 State ends in A
# Episode 205 State ends in A
# Episode 206 State ends in A
# Episode 207 State ends in E
# Episode 208 State ends in A
# Episode 209 State ends in A
# Episode 210 State ends in A
# Episode 211 State ends in A
# Episode 212 State ends in A
# Episode 213 State ends in A
# Episode 214 State ends in A
# Episode 215 State ends in A
# Episode 216 State ends in A
# Episode 217 State ends in A
# Episode 218 State ends in A
# Episode 219 State ends in A
# Episode 220 State ends in A
# Episode 221 State ends in A
# Episode 222 State ends in A
# Episode 223 State ends in A
# Episode 224 State ends in A
# Episode 225 State ends in A
# Episode 226 State ends in E
# Episode 227 State ends in E
# Episode 228 State ends in A
# Episode 229 State ends in E
# Episode 230 State ends in A
# Episode 231 State ends in A
# Episode 232 State ends in A
# Episode 233 State ends in A
# Episode 234 State ends in A
# Episode 235 State ends in A
# Episode 236 State ends in A
# Episode 237 State ends in A
# Episode 238 State ends in A
# Episode 239 State ends in A
# Episode 240 State ends in A
# Episode 241 State ends in A
# Episode 242 State ends in A
# Episode 243 State ends in A
# Episode 244 State ends in A
# Episode 245 State ends in E
# Episode 246 State ends in A
# Episode 247 State ends in A
# Episode 248 State ends in A
# Episode 249 State ends in A
# Episode 250 State ends in A
# Episode 251 State ends in A
# Episode 252 State ends in A
# Episode 253 State ends in A
# Episode 254 State ends in A
# Episode 255 State ends in A
# Episode 256 State ends in A
# Episode 257 State ends in A
# Episode 258 State ends in A
# Episode 259 State ends in A
# Episode 260 State ends in A
# Episode 261 State ends in A
# Episode 262 State ends in A
# Episode 263 State ends in A
# Episode 264 State ends in A
# Episode 265 State ends in A
# Episode 266 State ends in A
# Episode 267 State ends in A
# Episode 268 State ends in A
# Episode 269 State ends in A
# Episode 270 State ends in E
# Episode 271 State ends in E
# Episode 272 State ends in E
# Episode 273 State ends in A
# Episode 274 State ends in A
# Episode 275 State ends in A
# Episode 276 State ends in A
# Episode 277 State ends in E
# Episode 278 State ends in A
# Episode 279 State ends in A
# Episode 280 State ends in A
# Episode 281 State ends in A
# Episode 282 State ends in A
# Episode 283 State ends in A
# Episode 284 State ends in A
# Episode 285 State ends in A
# Episode 286 State ends in A
# Episode 287 State ends in E
# Episode 288 State ends in A
# Episode 289 State ends in A
# Episode 290 State ends in A
# Episode 291 State ends in E
# Episode 292 State ends in A
# Episode 293 State ends in A
# Episode 294 State ends in A
# Episode 295 State ends in A
# Episode 296 State ends in E
# Episode 297 State ends in A
# Episode 298 State ends in E
# Episode 299 State ends in A
# Episode 300 State ends in A
# Episode 301 State ends in A
# Episode 302 State ends in A
# Episode 303 State ends in A
# Episode 304 State ends in A
# Episode 305 State ends in A
# Episode 306 State ends in A
# Episode 307 State ends in A
# Episode 308 State ends in A
# Episode 309 State ends in A
# Episode 310 State ends in E
# Episode 311 State ends in A
# Episode 312 State ends in A
# Episode 313 State ends in A
# Episode 314 State ends in A
# Episode 315 State ends in A
# Episode 316 State ends in A
# Episode 317 State ends in A
# Episode 318 State ends in A
# Episode 319 State ends in A
# Episode 320 State ends in A
# Episode 321 State ends in A
# Episode 322 State ends in A
# Episode 323 State ends in A
# Episode 324 State ends in A
# Episode 325 State ends in A
# Episode 326 State ends in A
# Episode 327 State ends in A
# Episode 328 State ends in A
# Episode 329 State ends in A
# Episode 330 State ends in A
# Episode 331 State ends in A
# Episode 332 State ends in A
# Episode 333 State ends in A
# Episode 334 State ends in A
# Episode 335 State ends in A
# Episode 336 State ends in A
# Episode 337 State ends in A
# Episode 338 State ends in A
# Episode 339 State ends in A
# Episode 340 State ends in A
# Episode 341 State ends in E
# Episode 342 State ends in E
# Episode 343 State ends in E
# Episode 344 State ends in A
# Episode 345 State ends in A
# Episode 346 State ends in A
# Episode 347 State ends in A
# Episode 348 State ends in E
# Episode 349 State ends in A
# Episode 350 State ends in A
# Episode 351 State ends in A
# Episode 352 State ends in A
# Episode 353 State ends in A
# Episode 354 State ends in A
# Episode 355 State ends in A
# Episode 356 State ends in A
# Episode 357 State ends in A
# Episode 358 State ends in A
# Episode 359 State ends in A
# Episode 360 State ends in A
# Episode 361 State ends in A
# Episode 362 State ends in A
# Episode 363 State ends in A
# Episode 364 State ends in A
# Episode 365 State ends in A
# Episode 366 State ends in A
# Episode 367 State ends in A
# Episode 368 State ends in A
# Episode 369 State ends in E
# Episode 370 State ends in A
# Episode 371 State ends in A
# Episode 372 State ends in A
# Episode 373 State ends in A
# Episode 374 State ends in A
# Episode 375 State ends in A
# Episode 376 State ends in A
# Episode 377 State ends in A
# Episode 378 State ends in E
# Episode 379 State ends in A
# Episode 380 State ends in A
# Episode 381 State ends in A
# Episode 382 State ends in A
# Episode 383 State ends in A
# Episode 384 State ends in E
# Episode 385 State ends in A
# Episode 386 State ends in A
# Episode 387 State ends in A
# Episode 388 State ends in A
# Episode 389 State ends in A
# Episode 390 State ends in A
# Episode 391 State ends in A
# Episode 392 State ends in A
# Episode 393 State ends in A
# Episode 394 State ends in A
# Episode 395 State ends in A
# Episode 396 State ends in A
# Episode 397 State ends in A
# Episode 398 State ends in E
# Episode 399 State ends in A
# Episode 400 State ends in A
# Episode 401 State ends in A
# Episode 402 State ends in A
# Episode 403 State ends in A
# Episode 404 State ends in A
# Episode 405 State ends in A
# Episode 406 State ends in A
# Episode 407 State ends in E
# Episode 408 State ends in A
# Episode 409 State ends in E
# Episode 410 State ends in A
# Episode 411 State ends in A
# Episode 412 State ends in A
# Episode 413 State ends in A
# Episode 414 State ends in A
# Episode 415 State ends in A
# Episode 416 State ends in A
# Episode 417 State ends in A
# Episode 418 State ends in E
# Episode 419 State ends in E
# Episode 420 State ends in A
# Episode 421 State ends in A
# Episode 422 State ends in A
# Episode 423 State ends in A
# Episode 424 State ends in A
# Episode 425 State ends in A
# Episode 426 State ends in A
# Episode 427 State ends in E
# Episode 428 State ends in A
# Episode 429 State ends in A
# Episode 430 State ends in A
# Episode 431 State ends in A
# Episode 432 State ends in A
# Episode 433 State ends in A
# Episode 434 State ends in A
# Episode 435 State ends in A
# Episode 436 State ends in A
# Episode 437 State ends in A
# Episode 438 State ends in A
# Episode 439 State ends in A
# Episode 440 State ends in A
# Episode 441 State ends in A
# Episode 442 State ends in A
# Episode 443 State ends in E
# Episode 444 State ends in E
# Episode 445 State ends in A
# Episode 446 State ends in A
# Episode 447 State ends in A
# Episode 448 State ends in A
# Episode 449 State ends in A
# Episode 450 State ends in A
# Episode 451 State ends in A
# Episode 452 State ends in A
# Episode 453 State ends in A
# Episode 454 State ends in A
# Episode 455 State ends in A
# Episode 456 State ends in A
# Episode 457 State ends in E
# Episode 458 State ends in A
# Episode 459 State ends in A
# Episode 460 State ends in E
# Episode 461 State ends in A
# Episode 462 State ends in A
# Episode 463 State ends in E
# Episode 464 State ends in A
# Episode 465 State ends in A
# Episode 466 State ends in A
# Episode 467 State ends in A
# Episode 468 State ends in A
# Episode 469 State ends in A
# Episode 470 State ends in A
# Episode 471 State ends in A
# Episode 472 State ends in A
# Episode 473 State ends in A
# Episode 474 State ends in A
# Episode 475 State ends in A
# Episode 476 State ends in E
# Episode 477 State ends in A
# Episode 478 State ends in A
# Episode 479 State ends in A
# Episode 480 State ends in A
# Episode 481 State ends in A
# Episode 482 State ends in A
# Episode 483 State ends in A
# Episode 484 State ends in E
# Episode 485 State ends in A
# Episode 486 State ends in A
# Episode 487 State ends in A
# Episode 488 State ends in A
# Episode 489 State ends in A
# Episode 490 State ends in A
# Episode 491 State ends in A
# Episode 492 State ends in A
# Episode 493 State ends in A
# Episode 494 State ends in A
# Episode 495 State ends in A
# Episode 496 State ends in A
# Episode 497 State ends in A
# Episode 498 State ends in A
# Episode 499 State ends in A
# Episode 500 State ends in A
# Episode 501 State ends in E
# Episode 502 State ends in A
# Episode 503 State ends in A
# Episode 504 State ends in A
# Episode 505 State ends in A
# Episode 506 State ends in A
# Episode 507 State ends in A
# Episode 508 State ends in A
# Episode 509 State ends in A
# Episode 510 State ends in A
# Episode 511 State ends in A
# Episode 512 State ends in A
# Episode 513 State ends in A
# Episode 514 State ends in A
# Episode 515 State ends in A
# Episode 516 State ends in A
# Episode 517 State ends in E
# Episode 518 State ends in E
# Episode 519 State ends in A
# Episode 520 State ends in A
# Episode 521 State ends in A
# Episode 522 State ends in A
# Episode 523 State ends in A
# Episode 524 State ends in A
# Episode 525 State ends in A
# Episode 526 State ends in A
# Episode 527 State ends in A
# Episode 528 State ends in A
# Episode 529 State ends in A
# Episode 530 State ends in A
# Episode 531 State ends in A
# Episode 532 State ends in A
# Episode 533 State ends in A
# Episode 534 State ends in A
# Episode 535 State ends in A
# Episode 536 State ends in A
# Episode 537 State ends in A
# Episode 538 State ends in A
# Episode 539 State ends in A
# Episode 540 State ends in A
# Episode 541 State ends in A
# Episode 542 State ends in A
# Episode 543 State ends in A
# Episode 544 State ends in A
# Episode 545 State ends in A
# Episode 546 State ends in A
# Episode 547 State ends in A
# Episode 548 State ends in A
# Episode 549 State ends in E
# Episode 550 State ends in A
# Episode 551 State ends in A
# Episode 552 State ends in E
# Episode 553 State ends in A
# Episode 554 State ends in A
# Episode 555 State ends in A
# Episode 556 State ends in A
# Episode 557 State ends in A
# Episode 558 State ends in A
# Episode 559 State ends in A
# Episode 560 State ends in A
# Episode 561 State ends in A
# Episode 562 State ends in A
# Episode 563 State ends in A
# Episode 564 State ends in A
# Episode 565 State ends in A
# Episode 566 State ends in A
# Episode 567 State ends in A
# Episode 568 State ends in A
# Episode 569 State ends in A
# Episode 570 State ends in A
# Episode 571 State ends in A
# Episode 572 State ends in A
# Episode 573 State ends in A
# Episode 574 State ends in E
# Episode 575 State ends in A
# Episode 576 State ends in A
# Episode 577 State ends in A
# Episode 578 State ends in A
# Episode 579 State ends in E
# Episode 580 State ends in E
# Episode 581 State ends in E
# Episode 582 State ends in A
# Episode 583 State ends in A
# Episode 584 State ends in A
# Episode 585 State ends in A
# Episode 586 State ends in A
# Episode 587 State ends in A
# Episode 588 State ends in E
# Episode 589 State ends in E
# Episode 590 State ends in A
# Episode 591 State ends in A
# Episode 592 State ends in A
# Episode 593 State ends in E
# Episode 594 State ends in A
# Episode 595 State ends in A
# Episode 596 State ends in A
# Episode 597 State ends in A
# Episode 598 State ends in A
# Episode 599 State ends in A
# Episode 600 State ends in A
# Episode 601 State ends in A
# Episode 602 State ends in A
# Episode 603 State ends in E
# Episode 604 State ends in A
# Episode 605 State ends in A
# Episode 606 State ends in A
# Episode 607 State ends in A
# Episode 608 State ends in A
# Episode 609 State ends in A
# Episode 610 State ends in A
# Episode 611 State ends in A
# Episode 612 State ends in A
# Episode 613 State ends in E
# Episode 614 State ends in A
# Episode 615 State ends in A
# Episode 616 State ends in A
# Episode 617 State ends in A
# Episode 618 State ends in E
# Episode 619 State ends in E
# Episode 620 State ends in A
# Episode 621 State ends in A
# Episode 622 State ends in A
# Episode 623 State ends in A
# Episode 624 State ends in A
# Episode 625 State ends in A
# Episode 626 State ends in A
# Episode 627 State ends in E
# Episode 628 State ends in A
# Episode 629 State ends in E
# Episode 630 State ends in A
# Episode 631 State ends in A
# Episode 632 State ends in A
# Episode 633 State ends in A
# Episode 634 State ends in A
# Episode 635 State ends in A
# Episode 636 State ends in A
# Episode 637 State ends in A
# Episode 638 State ends in A
# Episode 639 State ends in A
# Episode 640 State ends in A
# Episode 641 State ends in A
# Episode 642 State ends in A
# Episode 643 State ends in A
# Episode 644 State ends in A
# Episode 645 State ends in A
# Episode 646 State ends in E
# Episode 647 State ends in A
# Episode 648 State ends in A
# Episode 649 State ends in A
# Episode 650 State ends in A
# Episode 651 State ends in E
# Episode 652 State ends in A
# Episode 653 State ends in A
# Episode 654 State ends in E
# Episode 655 State ends in A
# Episode 656 State ends in A
# Episode 657 State ends in A
# Episode 658 State ends in E
# Episode 659 State ends in A
# Episode 660 State ends in A
# Episode 661 State ends in A
# Episode 662 State ends in A
# Episode 663 State ends in E
# Episode 664 State ends in A
# Episode 665 State ends in A
# Episode 666 State ends in A
# Episode 667 State ends in A
# Episode 668 State ends in A
# Episode 669 State ends in A
# Episode 670 State ends in A
# Episode 671 State ends in A
# Episode 672 State ends in E
# Episode 673 State ends in A
# Episode 674 State ends in A
# Episode 675 State ends in A
# Episode 676 State ends in A
# Episode 677 State ends in A
# Episode 678 State ends in A
# Episode 679 State ends in A
# Episode 680 State ends in A
# Episode 681 State ends in A
# Episode 682 State ends in E
# Episode 683 State ends in E
# Episode 684 State ends in A
# Episode 685 State ends in A
# Episode 686 State ends in A
# Episode 687 State ends in A
# Episode 688 State ends in A
# Episode 689 State ends in E
# Episode 690 State ends in A
# Episode 691 State ends in A
# Episode 692 State ends in A
# Episode 693 State ends in A
# Episode 694 State ends in E
# Episode 695 State ends in A
# Episode 696 State ends in E
# Episode 697 State ends in A
# Episode 698 State ends in A
# Episode 699 State ends in A
# Episode 700 State ends in A
# Episode 701 State ends in E
# Episode 702 State ends in E
# Episode 703 State ends in A
# Episode 704 State ends in A
# Episode 705 State ends in A
# Episode 706 State ends in A
# Episode 707 State ends in A
# Episode 708 State ends in A
# Episode 709 State ends in A
# Episode 710 State ends in E
# Episode 711 State ends in A
# Episode 712 State ends in A
# Episode 713 State ends in A
# Episode 714 State ends in A
# Episode 715 State ends in A
# Episode 716 State ends in A
# Episode 717 State ends in A
# Episode 718 State ends in A
# Episode 719 State ends in E
# Episode 720 State ends in A
# Episode 721 State ends in A
# Episode 722 State ends in A
# Episode 723 State ends in A
# Episode 724 State ends in A
# Episode 725 State ends in A
# Episode 726 State ends in A
# Episode 727 State ends in E
# Episode 728 State ends in A
# Episode 729 State ends in A
# Episode 730 State ends in E
# Episode 731 State ends in A
# Episode 732 State ends in A
# Episode 733 State ends in A
# Episode 734 State ends in A
# Episode 735 State ends in A
# Episode 736 State ends in A
# Episode 737 State ends in A
# Episode 738 State ends in A
# Episode 739 State ends in A
# Episode 740 State ends in A
# Episode 741 State ends in A
# Episode 742 State ends in A
# Episode 743 State ends in A
# Episode 744 State ends in A
# Episode 745 State ends in A
# Episode 746 State ends in A
# Episode 747 State ends in A
# Episode 748 State ends in E
# Episode 749 State ends in A
# Episode 750 State ends in A
# Episode 751 State ends in A
# Episode 752 State ends in E
# Episode 753 State ends in A
# Episode 754 State ends in A
# Episode 755 State ends in A
# Episode 756 State ends in A
# Episode 757 State ends in A
# Episode 758 State ends in A
# Episode 759 State ends in A
# Episode 760 State ends in A
# Episode 761 State ends in A
# Episode 762 State ends in A
# Episode 763 State ends in E
# Episode 764 State ends in E
# Episode 765 State ends in A
# Episode 766 State ends in A
# Episode 767 State ends in E
# Episode 768 State ends in A
# Episode 769 State ends in A
# Episode 770 State ends in A
# Episode 771 State ends in A
# Episode 772 State ends in A
# Episode 773 State ends in A
# Episode 774 State ends in A
# Episode 775 State ends in A
# Episode 776 State ends in E
# Episode 777 State ends in A
# Episode 778 State ends in E
# Episode 779 State ends in A
# Episode 780 State ends in E
# Episode 781 State ends in A
# Episode 782 State ends in A
# Episode 783 State ends in A
# Episode 784 State ends in A
# Episode 785 State ends in A
# Episode 786 State ends in E
# Episode 787 State ends in A
# Episode 788 State ends in A
# Episode 789 State ends in A
# Episode 790 State ends in A
# Episode 791 State ends in A
# Episode 792 State ends in E
# Episode 793 State ends in A
# Episode 794 State ends in A
# Episode 795 State ends in A
# Episode 796 State ends in A
# Episode 797 State ends in A
# Episode 798 State ends in A
# Episode 799 State ends in A
# Episode 800 State ends in A
# Episode 801 State ends in A
# Episode 802 State ends in E
# Episode 803 State ends in A
# Episode 804 State ends in A
# Episode 805 State ends in A
# Episode 806 State ends in E
# Episode 807 State ends in A
# Episode 808 State ends in A
# Episode 809 State ends in A
# Episode 810 State ends in A
# Episode 811 State ends in A
# Episode 812 State ends in A
# Episode 813 State ends in A
# Episode 814 State ends in A
# Episode 815 State ends in A
# Episode 816 State ends in E
# Episode 817 State ends in A
# Episode 818 State ends in A
# Episode 819 State ends in A
# Episode 820 State ends in A
# Episode 821 State ends in A
# Episode 822 State ends in A
# Episode 823 State ends in E
# Episode 824 State ends in A
# Episode 825 State ends in A
# Episode 826 State ends in E
# Episode 827 State ends in A
# Episode 828 State ends in A
# Episode 829 State ends in A
# Episode 830 State ends in A
# Episode 831 State ends in A
# Episode 832 State ends in A
# Episode 833 State ends in A
# Episode 834 State ends in A
# Episode 835 State ends in A
# Episode 836 State ends in A
# Episode 837 State ends in E
# Episode 838 State ends in A
# Episode 839 State ends in E
# Episode 840 State ends in A
# Episode 841 State ends in A
# Episode 842 State ends in A
# Episode 843 State ends in A
# Episode 844 State ends in A
# Episode 845 State ends in A
# Episode 846 State ends in A
# Episode 847 State ends in A
# Episode 848 State ends in A
# Episode 849 State ends in A
# Episode 850 State ends in A
# Episode 851 State ends in A
# Episode 852 State ends in A
# Episode 853 State ends in A
# Episode 854 State ends in A
# Episode 855 State ends in A
# Episode 856 State ends in E
# Episode 857 State ends in E
# Episode 858 State ends in A
# Episode 859 State ends in A
# Episode 860 State ends in A
# Episode 861 State ends in E
# Episode 862 State ends in A
# Episode 863 State ends in A
# Episode 864 State ends in E
# Episode 865 State ends in A
# Episode 866 State ends in A
# Episode 867 State ends in A
# Episode 868 State ends in A
# Episode 869 State ends in A
# Episode 870 State ends in E
# Episode 871 State ends in A
# Episode 872 State ends in A
# Episode 873 State ends in E
# Episode 874 State ends in A
# Episode 875 State ends in E
# Episode 876 State ends in A
# Episode 877 State ends in A
# Episode 878 State ends in A
# Episode 879 State ends in A
# Episode 880 State ends in A
# Episode 881 State ends in A
# Episode 882 State ends in A
# Episode 883 State ends in A
# Episode 884 State ends in E
# Episode 885 State ends in E
# Episode 886 State ends in A
# Episode 887 State ends in A
# Episode 888 State ends in A
# Episode 889 State ends in A
# Episode 890 State ends in A
# Episode 891 State ends in A
# Episode 892 State ends in A
# Episode 893 State ends in A
# Episode 894 State ends in A
# Episode 895 State ends in A
# Episode 896 State ends in A
# Episode 897 State ends in A
# Episode 898 State ends in A
# Episode 899 State ends in A
# Episode 900 State ends in E
# Episode 901 State ends in A
# Episode 902 State ends in A
# Episode 903 State ends in A
# Episode 904 State ends in A
# Episode 905 State ends in A
# Episode 906 State ends in A
# Episode 907 State ends in A
# Episode 908 State ends in A
# Episode 909 State ends in A
# Episode 910 State ends in A
# Episode 911 State ends in A
# Episode 912 State ends in A
# Episode 913 State ends in A
# Episode 914 State ends in A
# Episode 915 State ends in A
# Episode 916 State ends in A
# Episode 917 State ends in A
# Episode 918 State ends in A
# Episode 919 State ends in E
# Episode 920 State ends in A
# Episode 921 State ends in A
# Episode 922 State ends in A
# Episode 923 State ends in A
# Episode 924 State ends in A
# Episode 925 State ends in A
# Episode 926 State ends in A
# Episode 927 State ends in A
# Episode 928 State ends in A
# Episode 929 State ends in A
# Episode 930 State ends in E
# Episode 931 State ends in A
# Episode 932 State ends in E
# Episode 933 State ends in A
# Episode 934 State ends in E
# Episode 935 State ends in A
# Episode 936 State ends in A
# Episode 937 State ends in E
# Episode 938 State ends in E
# Episode 939 State ends in E
# Episode 940 State ends in A
# Episode 941 State ends in A
# Episode 942 State ends in A
# Episode 943 State ends in A
# Episode 944 State ends in A
# Episode 945 State ends in A
# Episode 946 State ends in A
# Episode 947 State ends in A
# Episode 948 State ends in A
# Episode 949 State ends in A
# Episode 950 State ends in A
# Episode 951 State ends in A
# Episode 952 State ends in E
# Episode 953 State ends in A
# Episode 954 State ends in A
# Episode 955 State ends in A
# Episode 956 State ends in A
# Episode 957 State ends in A
# Episode 958 State ends in A
# Episode 959 State ends in A
# Episode 960 State ends in E
# Episode 961 State ends in A
# Episode 962 State ends in A
# Episode 963 State ends in A
# Episode 964 State ends in A
# Episode 965 State ends in A
# Episode 966 State ends in A
# Episode 967 State ends in A
# Episode 968 State ends in A
# Episode 969 State ends in A
# Episode 970 State ends in A
# Episode 971 State ends in A
# Episode 972 State ends in A
# Episode 973 State ends in A
# Episode 974 State ends in A
# Episode 975 State ends in A
# Episode 976 State ends in A
# Episode 977 State ends in A
# Episode 978 State ends in A
# Episode 979 State ends in A
# Episode 980 State ends in A
# Episode 981 State ends in E
# Episode 982 State ends in A
# Episode 983 State ends in A
# Episode 984 State ends in A
# Episode 985 State ends in A
# Episode 986 State ends in A
# Episode 987 State ends in A
# Episode 988 State ends in A
# Episode 989 State ends in A
# Episode 990 State ends in A
# Episode 991 State ends in A
# Episode 992 State ends in A
# Episode 993 State ends in A
# Episode 994 State ends in A
# Episode 995 State ends in A
# Episode 996 State ends in A
# Episode 997 State ends in A
# Episode 998 State ends in E
# Episode 999 State ends in A
# Episode 1000 State ends in A
# Agent went to A 868 times and E 132 times
# final weights: w1:[806.21666677 806.21666677 804.21666677] || w2: [7.42432125e+196 7.42432125e+196 7.42432125e+196]
